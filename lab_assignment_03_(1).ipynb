# %% [markdown]
# <a href="https://colab.research.google.com/github/RishithaPingili/Rishitha_INFO5502_Spring2022/blob/main/lab_assignment_03_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third Lab-assignment (02/10/2022, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points). Fomulate your domain problem: Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

Domain problem:
Data analysis for various toy prices in flipkart application.

Research question:
To get the original prices in the toys section for atleast 1000 records in the flipkart application.

Data required to answer the question:
Need the data of original prices without any deductions of toys that are obtained through web scraping of flipkart website for atleast 1000 toys.

These data sets can be obtained from the mentioned below link:
https://www.flipkart.com/search?q=toys&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4

Detailed steps for collecting and saving the data:
1) Import the necessary beautiful soup library in order to parse the html source code of the web page taken.
2) The next step is to inspect the data element in the html code by parsing it.
3) Iterate through few number of pages to get atleast 1000 samples from the respective section.
4) store the obtained MRP's in a list named MRP_list.
5) This list gives the data required , so then data cleaning and analysis can be done as required.


























'''

# %% [markdown]
# Question 2 (10 points). Collect your data to answer the research problem: Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

from bs4 import BeautifulSoup
import json
import re
import urllib
from urllib.request import Request, urlopen
from urllib.error import HTTPError

cnt = 0
mrp_list = []
flipkart_link = "https://www.flipkart.com/search?q=toys&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}"
for pg in range(1, 190):
    # iterating through 100 pages to get atleast 1000 records
    lnk = Request(flipkart_link.format(pg), headers={'User-Agent': 'Mozilla/5.0'})
    url = urlopen(lnk)

    dataset_1 = url.read()
    dtsoup = BeautifulSoup(dataset_1)

    # to go to the respective MRP price in the link where div class is _3I9_wc which belong to MRP
    for i in dtsoup.find_all('div', attrs = {'class':"_3I9_wc"}):
     
      mrp_list.append(i.text)
      # to make sure to get 1000 samples from the respective url 
      cnt = cnt + 1
      if cnt == 1001:
          break
    #to make sure it breaks the loop after collecting 1000 records.      
    if cnt == 1001:
        break

print(mrp_list)
# Out:
# Total no of samples: 999
# ...

# %% [markdown]
# Question 3 (10 points). Understand the data quality: Search a second hand dataset (any dataset) from kaggle or other websites. Describe the data quality problem of the dataset and explain your strtegy to clean the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
'''

Please write you answer here:

Dataset selected : NFL Play by Play 2009-2016 (v3).csv from kaggle.com

The dataset selected consists of multiple missing values in many of the fields, so data cleaning is required in this data set.
By observing the data set , we can observe that the column has information on the number of seconds left in the game when the play was made. 
So there might be a chance that these value are missing because they were not recorded or they doesnt exist.

Strategy to clean the data:
First common strategy is to 
1) Try to find the percentage of missing values in the dataset.
2) If the percentage of missing values is around 10% , delete the rows with the missing columns but if there are more missing values 
then there is a chance of many rows getting deleted.
3) If the percentage is more, then replace the missing values either with a constant value or mean/median if the data size is small.
4) There is also another way which is to replace it with values by using information based on other columns.






'''

# %% [markdown]
# Question 4 (20 points). Data cleaning: There are two datasets TwADR-L (from Twitter) and AskAPatient (Link: https://zenodo.org/record/55013#.YgU2NN-ZO4T) for medical concept
# normalization. However, the two datasets have serious data quality problems. Please read the introduction of the datasets and clean the two datasets by following the steps in the statement.
#
# In the original dataset, the TwADR-L had 48,057 training, 1,256 validation and 1,427 test examples. The test set (all
# test samples from 10 folds combined) consists of 765 unique phrases and 273 unique classes (medical concepts). The AskAPatient dataset contained 156,652 training, 7,926 validation, and 8,662 test examples. The entire test set (all test samples
# from 10 folds combined) consists of 3,749 unique phrases and 1,035 unique classes (medical concepts). The authors
# randomly split each dataset into ten equal folds, ran 10-fold cross validation and reported the accuracy averaged across the
# ten folds.
#
# We found that, in the original data set, many phrase-label pairs appeared multiple times within the same training data file
# and also across the training and test data sets in the same fold. In the AskAPatient data set, on average 35.82% of the test data overlapped with training data in the same fold. In the Twitter (TwADR-L) dataset, on average 8.62% of the test set had an overlap with the training data in the same fold. Having a large overlap between the training and the test data can potentially
# introduce bias in the model and contribute to high accuracy. It is not unlikely that the high model performance reported in the original paper may be triggered by the the large overlap between the training and test sets.
#
# Therefore to remove the bias, we further cleaned and recreated the training, validation, and test sets such that each
# phrase-label pair appears only once in the entire dataset (either in training, validation or test set).
#
# (1) First, we combined all examples in training, validation and test data from the original data set and then removed all
# duplicate phrase-label pairs (examples that have the same phrase and label pair and appear more than once in training/validation/test datasets). Table II shows the statistics of the new dataset (after removing duplicates). The Twitter data set had 3,157 unique phrase-label pairs and 2,220 unique labels (medical concepts) while 173 phrases had multiple labels (i.e., they were assigned to more than one label). Many concepts had only one example, and the concept that had the most number
# of examples had 36 phrases. On average, each concept had 1.42 examples. The AskAPatient data set had 4,496 unique phrase-label pairs, 1,036 unique labels while 26 phrases had multiple labels. Table III shows examples of phrases that had multiple labels. For example, ‘mad’ can be mapped to ‘anger’ or ‘rage’ and ‘sore’ can be mapped to ‘pain’ or ‘myalgia’.
#
# (2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
#
# (3) Third, we divide all examples without multiple labels into random 10 folds such that each unique phrase-label pair
# appears once in one of the 10 test sets. We add the pairs with multiple labels into the training data. This final 10-folds
# dataset is used in all our experiments.
#
# (The original paper can be download on canvas)

# %%
#mounting google drive memory to upload the data folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# You code here (Please add comments in the code):

# 1.) output
import pandas as pd
import glob
out_df =  pd.DataFrame() 
for dataset in ['TwADR-L', 'AskAPatient']:
  output = {}
  data_df = pd.DataFrame()
  for path in glob.glob('/content/gdrive/My Drive/datasets/{}/*.txt'.format(dataset)):
    dt = pd.read_csv(path, sep = "\t", header = None, encoding= 'unicode_escape')
    data_df = data_df.append(dt)
  data_df = data_df.reset_index(drop=True)
  data_df['phrase_label'] = data_df[1] + " " + data_df[2]
  data_df.columns = ['id', 'labels', 'phrases', 'phrase-label']
  data_df = data_df.astype({"id": str})
  for col in data_df.columns:
      data_df[col] = data_df[col].str.lower() 

  data_df = data_df.drop_duplicates('phrase-label')

  # storing output of the values in form of dictionary and then giving it to dataframe
  output['Unique Phrases'] = len(data_df['phrases'].unique())
  output['Unique Labels'] = len(data_df['labels'].unique())
  output['Unique phrase_label pairs'] = data_df.shape[0]
  data_df1 = pd.DataFrame(data_df['phrases'].value_counts())
  output['Phrases with multiple labels'] = data_df1[data_df1['phrases'] > 1].shape[0]
  output['Min examples per label'] = data_df['labels'].value_counts().values.min()
  output['Max examples per label'] = data_df['labels'].value_counts().values.max()
  output['Avg examples per label'] = round(data_df['labels'].value_counts().mean(), 2)
  out_df = out_df.append(output, ignore_index=True)


out_df = out_df.T
out_df.columns = ['TwADR-L', 'AskAPatient']

out_df
# Out:
#                               TwADR-L  AskAPatient
# Unique Phrases                2944.00      4470.00
# Unique Labels                 2220.00      1038.00
# Unique phrase_label pairs     3157.00      4507.00
# Phrases with multiple labels   173.00        35.00
# Min examples per label           1.00         1.00
# Max examples per label          36.00       141.00
# Avg examples per label           1.42         4.34

# %%
# 2.)
import pandas as pd
import glob
out_df1 = pd.DataFrame()
for dataset in ['TwADR-L', 'AskAPatient']:
    data_df1 = pd.DataFrame()
    output = {}
    for path1 in glob.glob('/content/gdrive/My Drive/datasets/{}/*.txt'.format(dataset)):
        dt = pd.read_csv(path1, sep = "\t", header = None, encoding= 'unicode_escape')
        data_df1 = data_df1.append(dt)
    data_df1 = data_df1.reset_index(drop=True)
    data_df1['phrase_label'] = data_df1[1] + " " + data_df1[2]
    data_df1.columns = ['id', 'labels', 'phrases', 'phrase-label']
    data_df1 = data_df1.astype({"id": str})
    # converting the values to lower case
    for colmn in data_df1.columns:
        data_df1[colmn] = data_df1[colmn].str.lower() 

    # inbuilt drop duplictes function is being used to avoid duplicates
    data_df1 = data_df1.drop_duplicates('phrase-label')

    index_list = []
    for i in range(data_df1.shape[0]):
        if data_df1['labels'].value_counts()[data_df1.iloc[i]['labels']] < 5:
            index_list.append(i)
    data_df1.drop(data_df1.index[index_list], inplace=True)
    output = {}
    output['Unique phrases'] = len(data_df1['phrases'].unique())
    output['Unique labels'] = len(data_df1['labels'].unique())
    output['Unique phrase_label pairs'] = data_df1.shape[0]
    data_df11 = pd.DataFrame(data_df1['phrases'].value_counts())
    output['Phrases with multiple labels'] = data_df11[data_df11['phrases'] > 1].shape[0]
    output['Min examples per label'] = data_df1['labels'].value_counts().values.min()
    output['Max examples per label'] = data_df1['labels'].value_counts().values.max()
    output['Avg examples per label'] = round(data_df1['labels'].value_counts().mean(), 2)
    out_df1 = out_df1.append(output, ignore_index=True)

out_df1 = out_df1.T
out_df1.columns = ['TwADR-L', 'AskAPatient']

out_df1
# Out:
#                               TwADR-L  AskAPatient
# Unique phrases                 616.00      2665.00
# Unique labels                   76.00       233.00
# Unique phrase_label pairs      721.00      2686.00
# Phrases with multiple labels    87.00        19.00
# Min examples per label           5.00         5.00
# Max examples per label          36.00       141.00
# Avg examples per label           9.49        11.53
